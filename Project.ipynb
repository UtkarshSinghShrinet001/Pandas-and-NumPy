# %% [markdown]
# ![Screenshot 2024-06-18 120357.png](attachment:fc6a9069-50c8-4e7e-ab96-38c6eeb1ffd4.png)

# %% [markdown]
# # Index

# %% [markdown]
# # List of Tables

# %% [markdown]
# # List of Figures

# %% [markdown]
# # Problem Statement / Objective :

# %% [markdown]
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape. By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience. The analysis will provide valuable insights and recommendations for stakeholders in the education sector.
# Data Description
# •	Names: Names of various university and colleges
# •	Apps: Number of applications received
# •	Accept: Number of applications accepted
# •	Enroll: Number of new students enrolled
# •	Top10perc: Percentage of new students from top 10% of Higher Secondary class
# •	Top25perc: Percentage of new students from top 25% of Higher Secondary class
# •	F.Undergrad: Number of full-time undergraduate students
# •	P.Undergrad: Number of part-time undergraduate students
# •	Outstate: Number of students for whom the particular college or university is Out-of-state tuition
# •	Room.Board: Cost of Room and board
# •	Books: Estimated book costs for a student
# •	Personal: Estimated personal spending for a student
# •	PhD: Percentage of faculties with Ph.D.’s
# •	Terminal: Percentage of faculties with terminal degree
# •	S.F.Ratio: Student/faculty ratio
# •	perc.alumni: Percentage of alumni who donate
# •	Expend: The Instructional expenditure per student
# •	Grad.Rate: Graduation rate

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\troof'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('1-Education_Post_12th_Standard_New.csv')

# %% [markdown]
# # 1. FIRST FIVE ELEMENTS OF DATA

# %%
data.head().T
# Out:
#                                         0                   1               2  \
# Names        Abilene Christian University  Adelphi University  Adrian College
# Apps                               1660.0              2186.0          1428.0
# Accept                               1232                1924            1097
# Enroll                              721.0               512.0           336.0
# Top10perc                            23.0                16.0            22.0
# Top25perc                              52                  29              50
# F.Undergrad                          2885                2683            1036
# P.Undergrad                           537                1227              99
# Outstate                             7440               12280           11250
# Room.Board                           3300                6450            3750
# Books                                 450                 750             400
# ...

# %% [markdown]
# # 2. LAST FIVE ELEMENTS OF DATA

# %%
data.tail().T
# Out:
#                                  772                773  \
# Names        Worcester State College  Xavier University
# Apps                          2197.0             1959.0
# Accept                          1515               1805
# Enroll                         543.0              695.0
# Top10perc                        4.0               24.0
# Top25perc                         26                 47
# F.Undergrad                     3089               2849
# P.Undergrad                     2029               1107
# Outstate                        6797              11520
# Room.Board                      3900               4960
# Books                            500                600
# Personal                      1200.0             1250.0
# PhD                               60                 73
# Terminal                          60                 75
# S.F.Ratio                         21               13.3
# perc.alumni                       14                 31
# ...

# %% [markdown]
# # 3. DATA SHAPE

# %%
data.shape
# Out:
# (777, 18)

# %% [markdown]
# # 4. DATA TYPES

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        777 non-null    object
#  1   Apps         775 non-null    float64
#  2   Accept       777 non-null    int64
#  3   Enroll       775 non-null    float64
#  4   Top10perc    773 non-null    float64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     774 non-null    float64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    object
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# ...

# %% [markdown]
# # 5. STATICAL SUMMARY

# %%
data.describe().T
# Out:
#              count          mean          std     min     25%     50%  \
# Apps         775.0   3007.592258  3873.414660    81.0   778.0  1561.0
# Accept       777.0   2018.804376  2451.113971    72.0   604.0  1110.0
# Enroll       775.0    780.961290   930.077779    35.0   242.5   434.0
# Top10perc    773.0     27.620957    17.645470     1.0    15.0    23.0
# Top25perc    777.0     55.796654    19.804778     9.0    41.0    54.0
# F.Undergrad  777.0   3699.907336  4850.420531   139.0   992.0  1707.0
# P.Undergrad  777.0    855.298584  1522.431887     1.0    95.0   353.0
# Outstate     777.0  10440.669241  4023.016484  2340.0  7320.0  9990.0
# Room.Board   777.0   4357.526384  1096.696416  1780.0  3597.0  4200.0
# Books        777.0    547.875161   167.426237     0.0   465.0   500.0
# Personal     774.0   1601.507752  7369.594038    50.0   855.0  1200.0
# PhD          777.0     72.660232    16.328155     8.0    62.0    75.0
# ...

# %% [markdown]
# # 6. CHECK FOR THE NULL VALUES

# %%
data.isnull().T
# Out:
#                0      1      2      3      4      5      6      7      8    \
# Names        False  False  False  False  False  False  False  False  False
# Apps         False  False  False  False  False  False  False  False  False
# Accept       False  False  False  False  False  False  False  False  False
# Enroll       False  False  False   True  False  False  False  False  False
# Top10perc    False  False  False  False  False  False  False  False  False
# Top25perc    False  False  False  False  False  False  False  False  False
# F.Undergrad  False  False  False  False  False  False  False  False  False
# P.Undergrad  False  False  False  False  False  False  False  False  False
# Outstate     False  False  False  False  False  False  False  False  False
# Room.Board   False  False  False  False  False  False  False  False  False
# Books        False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# # 7. CHECK FOR DUPLICATE VALUES

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# Length: 777, dtype: bool

# %% [markdown]
# # 8. CHECK FOR OUTLIERS

# %%
plt.figure(figsize= (7,7))
sns.boxplot(data= data,orient = 'h');

# %% [markdown]
# # 9. CHECK FOR WRONG VALUES

# %%
data[data["S.F.Ratio"]=='?']
# Out:
#                      Names    Apps  Accept  Enroll  Top10perc  Top25perc  \
# 1       Adelphi University  2186.0    1924   512.0       16.0         29
# 81     Campbell University  2087.0    1339     NaN       20.0         54
# 241  Gwynedd Mercy College   380.0     237   104.0       30.0         56
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 1           2683         1227     12280        6450    750    1500.0   29
# 81          3191         1204      7550        2790    600     500.0   77
# 241          716         1108     11000        5550    500     500.0   36
#
#      Terminal S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 1          30         ?           16   10527         56
# 81         77         ?           34    3739         63
# 241        41         ?           22    7483         96

# %% [markdown]
# # 10. REPLACING "?" WITH NAN VALUE

# %%
data["S.F.Ratio"]=data["S.F.Ratio"].replace('?',np.nan)
data.head().T
# Out:
#                                         0                   1               2  \
# Names        Abilene Christian University  Adelphi University  Adrian College
# Apps                               1660.0              2186.0          1428.0
# Accept                               1232                1924            1097
# Enroll                              721.0               512.0           336.0
# Top10perc                            23.0                16.0            22.0
# Top25perc                              52                  29              50
# F.Undergrad                          2885                2683            1036
# P.Undergrad                           537                1227              99
# Outstate                             7440               12280           11250
# Room.Board                           3300                6450            3750
# Books                                 450                 750             400
# ...

# %% [markdown]
# # I. Application And Enrollment Analysis

# %% [markdown]
# # 1. Average number of application received by the college

# %%
data['Apps'].mean()
# Out:
# 3007.592258064516

# %% [markdown]
# # 2. Percentage of apllications are accecpted by the colleges

# %%
(data['Accept'].sum() / data['Apps'].sum())*100
# Out:
# 67.29682815618452

# %% [markdown]
# # 3. Avg. enrollment rate

# %%
(data['Enroll'].sum() / data['Accept'].sum())
# Out:
# 0.3858477340781111

# %% [markdown]
# # 4. college with highest applications received

# %%
data.loc[data['Apps'].idxmax(),'Names']
# Out:
# 'Rutgers at New Brunswick'

# %% [markdown]
#  # II. ACADEMIC EXCELLENCE

# %% [markdown]
# # 1. Average percen. of new students from the top 10 perc.

# %%
(data['Top10perc'].mean())
# Out:
# 27.620957309184995

# %% [markdown]
# # 2. Average percen. of new students from the top 25 perc.

# %%
(data['Top25perc'].mean())
# Out:
# 55.7966537966538

# %% [markdown]
# # III. STUDENTS DEMOGRAPHICS

# %% [markdown]
# # 1. Avg. number of fulltime ungraduatred studednts

# %%
data['F.Undergrad'].mean()
# Out:
# 3699.907335907336

# %% [markdown]
# # 2. Avg. number of part-time ungraduatred studednts

# %%
data['P.Undergrad'].mean()
# Out:
# 855.2985842985843

# %% [markdown]
# # 3. College with highest number of out-of-state students

# %%
data.loc[data['Outstate'].idxmax(),'Names']
# Out:
# 'Bennington College'

# %% [markdown]
# # IV. COST AND SPENDINGS

# %% [markdown]
# # 1. Cost of rooms and boards across the colleges

# %%
data['Room.Board'].mean()
# Out:
# 4357.526383526383

# %% [markdown]
# # 2. Avg books cost

# %%
data['Books'].mean()
# Out:
# 547.8751608751609

# %% [markdown]
# # 3. Avg spending personal of students

# %%
data['Personal'].mean()
# Out:
# 1601.5077519379845

# %% [markdown]
# # V. FACULTY QUALIFICATIONS

# %% [markdown]
# # 1. Avg percentage of PhDS across colleges

# %%
data['PhD'].mean()
# Out:
# 72.66023166023166

# %% [markdown]
# # 2.  Avg percentage of PhDS with terminal degrees

# %%
data['Terminal'].mean()
# Out:
# 79.70270270270271
